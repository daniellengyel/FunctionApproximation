# %%
import numpy as np
import jax.numpy as jnp
import jax.random as jrandom

import sys


HOME = "/rds/general/user/dl2119/home/ICLR_Interp" # Path(os.environ["PATH_INTP_FOLDER"])
sys.path.append(HOME)
sys.path.append(HOME + "/DataGeneration/CurvSampling")
from CurvSampling import sample_curv
from UniformData import get_uniform_random

from chart_studio import plotly as py
import plotly.graph_objs as go
import matplotlib.pyplot as plt

from Functions import get_func
from DataAnalysis import curv

import os

import time

from jax.config import config
config.update("jax_enable_x64", True)

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
num_steps = 50
sig = 0.5
seed = 0
eps_barrier = 3
func_name = "Schwefel"
dim = 6
N = 100000
curv_scaling = 150
# #     "Schwefel": {
#         "num_steps": 50,
#         "sig": 0.5,
#         "eta": 1,
#         "seed": 0,
#         "eps_barrier": 5,
#         "curv_scaling": 100
#     },

F = get_func(func_name)

a = time.time()
path = sample_curv(F, dim, N, num_steps, sig, seed, eps_barrier, curv_scaling=curv_scaling, full_path=True)

last_elem = path[-1]
path = jnp.array(path)
time.time() - a
# Out:
# 15.481944799423218

# %%
y = F.f(path[-1])

print(jnp.max(y))
print(jnp.min(y))
# Out:
# 1.308830118854152e+40
# -1.5083954211964366e+40

# %%
X_data = get_uniform_random(F, N, dim, seed)

plt.hist(np.array(curv(F, last_elem)), bins=30)

plt.hist(np.array(curv(F, X_data)), bins=30)


# plt.xlim(0, 1)
# Out:
# (array([9.9999e+04, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([6.13839417e-02, 2.29533463e+01, 4.58453087e+01, 6.87372711e+01,
#         9.16292335e+01, 1.14521196e+02, 1.37413158e+02, 1.60305121e+02,
#         1.83197083e+02, 2.06089045e+02, 2.28981008e+02, 2.51872970e+02,
#         2.74764933e+02, 2.97656895e+02, 3.20548857e+02, 3.43440820e+02,
#         3.66332782e+02, 3.89224745e+02, 4.12116707e+02, 4.35008669e+02,
#         4.57900632e+02, 4.80792594e+02, 5.03684557e+02, 5.26576519e+02,
#         5.49468481e+02, 5.72360444e+02, 5.95252406e+02, 6.18144369e+02,
#         6.41036331e+02, 6.63928293e+02, 6.86820256e+02]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(np.array(last_elem[:, 0]), bins=30)
# Out:
# (array([1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 3.0000e+00, 9.9991e+04, 1.0000e+00, 3.0000e+00]),
#  array([-4.84556029e+39, -4.67013938e+39, -4.49471847e+39, -4.31929756e+39,
#         -4.14387665e+39, -3.96845574e+39, -3.79303483e+39, -3.61761392e+39,
#         -3.44219301e+39, -3.26677210e+39, -3.09135119e+39, -2.91593028e+39,
#         -2.74050937e+39, -2.56508845e+39, -2.38966754e+39, -2.21424663e+39,
#         -2.03882572e+39, -1.86340481e+39, -1.68798390e+39, -1.51256299e+39,
#         -1.33714208e+39, -1.16172117e+39, -9.86300264e+38, -8.10879354e+38,
#         -6.35458443e+38, -4.60037533e+38, -2.84616623e+38, -1.09195713e+38,
#          6.62251972e+37,  2.41646107e+38,  4.17067017e+38]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist(np.array(path[1][:, 0]), bins=30)
# Out:
# (array([3.000e+00, 1.000e+00, 9.999e+04, 2.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([-16152.37095185,  -9535.49148979,  -2918.61202774,   3698.26743431,
#          10315.14689636,  16932.02635842,  23548.90582047,  30165.78528252,
#          36782.66474458,  43399.54420663,  50016.42366868,  56633.30313074,
#          63250.18259279,  69867.06205484,  76483.9415169 ,  83100.82097895,
#          89717.700441  ,  96334.57990306, 102951.45936511, 109568.33882716,
#         116185.21828921, 122802.09775127, 129418.97721332, 136035.85667537,
#         142652.73613743, 149269.61559948, 155886.49506153, 162503.37452359,
#         169120.25398564, 175737.13344769, 182354.01290975]),
#  <BarContainer object of 30 artists>)

# %%
def get_line_along_v(F, v, N):
    """Goes through the center of the cube"""
    v = v / jnp.linalg.norm(v)
    c = jnp.mean(F.bounds, axis=1)
    # when does t*v + c cross boundary. 
    # bounds[:, 0] \leq c + t v \leq bounds[:, 1]
    # ts_low \leq t \leq ts_high. with ts_low \leq 0 and ts_high \geq 0. 
    # hence, of all negatives we need the largetst and all positives the smallest. 
    # because c is the center, we have t_low = -t_high
    
    t0s =  (F.bounds[:, 0] - c)/v
    t1s =  (F.bounds[:, 1] - c)/v
    t_idx = jnp.argmin(jnp.abs(t0s))
    
    t0 = t0s[t_idx]
    t1 = t1s[t_idx]
    
    print(t1)
    
    xs = (c + t0 * v) + jnp.linspace(0, 1, N).reshape(-1, 1) * (c + t1 * v - (c + t0 * v))
    return xs

# %%
F.f2(xs_v)
# Out:
# DeviceArray([[[nan, nan],
#               [nan, nan]],
#
#              [[nan, nan],
#               [nan, nan]],
#
#              [[nan, nan],
#               [nan, nan]],
#
#              ...,
#
#              [[nan, nan],
#               [nan, nan]],
#
#              [[nan, nan],
#               [nan, nan]],
#
#              [[nan, nan],
#               [nan, nan]]], dtype=float64)

# %%
def f(X):
    c = 418.9829
    d = X.shape[0]
    return c * d - jnp.sum(jnp.sin(jnp.sqrt(jnp.abs(X))) * X)

# %%
from jax import grad

# %%
grad(f)(x)
# Out:
# DeviceArray([        nan, 10.78680913], dtype=float64)

# %%
F.f(x.reshape(1, -1))
# Out:
# DeviceArray([657.37664147], dtype=float64)

# %%
x = xs_v[0]

h = 0.000001

(f((x + h * jnp.eye(2)[0])) - f(x))/h
# Out:
# DeviceArray(-0.00099999, dtype=float64)

# %%
dim = 2
xs_v = get_line_along_v(F, jnp.array(range(dim)), N)
plt.plot(jnp.linspace(0, 1, N), curv(F, xs_v))
# Out:
# 500.0

# %%
def f(X):
    c = 418.9829
    d = X.shape[1]
    return c * d - jnp.sum(jnp.sin(jnp.sqrt(jnp.abs(X))) * X, axis=1)
#     return c * d - jnp.sum(jnp.sin(jnp.power(X**2, 1/4.)) * X, axis=1)

# %%
xs_v = get_line_along_v(F, jnp.array([0, 1]), N)
plt.plot(jnp.linspace(0, 1, N), F.f(xs_v))
plt.plot()
# plt.plot(jnp.linspace(0, 1, N), -curv(F, xs_v)*0.01)
# Out:
# 500.0

# %%
xs_v = get_line_along_v(F, jnp.array([1, -.5]), N)
plt.scatter(xs_v[:, 0], xs_v[:, 1])

# %%
plt.hist(np.array(curv(F, X)), bins=20)
# Out:
# (array([5.060e+02, 1.317e+03, 1.700e+02, 1.000e+00, 1.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([0.01367637, 0.25004077, 0.48640518, 0.72276959, 0.95913399,
#         1.1954984 , 1.43186281, 1.66822722, 1.90459162, 2.14095603,
#         2.37732044, 2.61368485, 2.85004925, 3.08641366, 3.32277807,
#         3.55914247, 3.79550688, 4.03187129, 4.2682357 , 4.5046001 ,
#         4.74096451]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(np.array(curv(F, path[-1])), bins=20)
# Out:
# (array([ 43.,  93., 133., 223., 378., 322., 299., 316., 156.,  20.,  11.,
#           3.,   1.,   1.,   0.,   0.,   0.,   0.,   0.,   1.]),
#  array([0.01470452, 0.0726    , 0.13049548, 0.18839097, 0.24628645,
#         0.30418194, 0.36207742, 0.4199729 , 0.47786839, 0.53576387,
#         0.59365935, 0.65155484, 0.70945032, 0.76734581, 0.82524129,
#         0.88313677, 0.94103226, 0.99892774, 1.05682323, 1.11471871,
#         1.17261419]),
#  <BarContainer object of 20 artists>)

# %%
a = time.time()
F.f1(X)
print(time.time() - a)
# Out:
# 0.000986337661743164

# %%
a = time.time()
F.f2(X)
print(time.time() - a)
# Out:
# 0.001432180404663086

# %%
N = 250

x = np.linspace(F.bounds[0][0], F.bounds[0][1], int(N))
y = np.linspace(F.bounds[0][0], F.bounds[0][1], int(N))
XY = np.meshgrid(x, y)

#define 2D points, as input data for the Delaunay triangulation of U
points2D=np.vstack([XY[0].ravel(), XY[1].ravel()]).T

z_quadrics_f = F.f(points2D).reshape(N, N)


axis = dict(
showbackground=True,
backgroundcolor="rgb(230, 230,230)",
gridcolor="rgb(255, 255, 255)",
zerolinecolor="rgb(255, 255, 255)",
    )

layout = go.Layout(
         title='triangulation',
         width=800,
         height=800,
         scene=dict(
         xaxis=dict(axis),
         yaxis=dict(axis),
         zaxis=dict(axis),
        aspectratio=dict(
            x=1,
            y=1,
            z=0.5
        ),
        )
        )

fig = go.Figure(data=[go.Surface(z=z_quadrics_f, x=x, y=y)], layout=layout)


fig.show()

# %%
z_quadrics_f.shape
