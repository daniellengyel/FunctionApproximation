# %%
import sys, os
import json
from pathlib import Path 
HOME = "/rds/general/user/dl2119/home/ICLR_Interp" # Path(os.environ["PATH_INTP_FOLDER"])
os.environ["PATH_INTP_FOLDER"] = HOME
HOME = Path(HOME)
sys.path.append(str(HOME))
sys.path.append(str(HOME / "DataGeneration"))
sys.path.append(str(HOME / "ModelGeneration"))

from save_load_data import load_fast
from save_load_model import save_nn
from nn_train import train

import torch
import torchvision
import torch.optim as optim
from torch import Tensor

import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Module

from torch.utils.data import DataLoader

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class SimpleNet(Module):
    def __init__(self, inp_dim, out_dim, width, num_layers, dropout_p=0, activation=None):
        super(SimpleNet, self).__init__()

        self.dropout_p = dropout_p
        
        if activation is None or activation == "relu":
            self.activation = F.relu
        if activation == "sigmoid":
            self.activation = F.hardsigmoid
        if activation == "tanh":
            self.activation = F.hardtanh

        self.fc_input = nn.Linear(inp_dim, width)
        self.layers = nn.ModuleList([nn.Linear(width, width) for _ in range(num_layers - 1)])
        self.fc_final = nn.Linear(width, out_dim)

    def forward(self, x):
        x = self.activation(self.fc_input(x))
        for i in range(len(self.layers)):
            x = self.activation(self.layers[i](x))
        x = self.fc_final(x)
        return x

# %%
def load_model(path):
    path = str(path)
    model_config = path.split("/")[-2]
    depth = model_config.split("_")[2]
    width = model_config.split("_")[4]
    dim = (path.split("/")[-5]).split("_")[1]
    
    depth = int(depth)
    width = int(width)
    dim = int(dim)
    
    model = SimpleNet(dim, 1, width, depth)
    model.load_state_dict(torch.load(path))
    model.eval()
    return model

# %%
model_dir_path = HOME / "Models"

res = {}

criterion = torch.nn.MSELoss(reduction="mean")


for func_name in os.listdir(model_dir_path):
    print(func_name)
    if func_name == "Schwefel":
        continue
    for dim in os.listdir(model_dir_path / func_name):
        print("dim", dim)
        for N in os.listdir(model_dir_path / func_name / dim):
            for data_gen_method in os.listdir(model_dir_path / func_name / dim / N):
                N_int = int(N.split("_")[1])
                dim_int = int(dim.split("_")[1])
                X_data, y_data = load_fast(func_name, dim_int, N_int, data_gen_method)
                X_data = Tensor(X_data)
                y_data = Tensor(y_data).unsqueeze(1)
                
                X_data = X_data.type(torch.float32)
                y_data = y_data.type(torch.float32)
                
                for nn_type in os.listdir(model_dir_path / func_name / dim / N / data_gen_method):
                    print(nn_type)
                    net = load_model(model_dir_path / func_name / dim / N / data_gen_method / nn_type / "model.pt")

                    # forward + backward + optimize
                    outputs = net(X_data)
                    loss = criterion(outputs, y_data)
                    print(loss)
                    
#                     with open(model_dir_path / func_name / dim / N / data_type / nn_type / "loss_hist.json", "rb") as f:
#                         loss_hist = json.load(f)
                    curr_dir = {"func_name": func_name, "dim": dim.split("_")[1], 
                                "N": N.split("_")[1], "data_type": data_gen_method, "nn_type": nn_type, "loss": loss}
# Out:
# Schwefel
# Michi
# dim dim_8
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_32_l2p_1
# tensor(0.8130, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_0.001
# tensor(0.4924, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_1
# tensor(0.9437, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_1
# tensor(0.8982, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_0.001
# tensor(0.3516, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_128_l2p_0
# tensor(0.6890, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_1
# tensor(0.9463, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_0
# tensor(0.7009, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6811, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_1
# tensor(0.9355, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6668, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_1
# tensor(0.9202, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_1
# tensor(0.8846, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_0
# tensor(2.6447, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_1
# tensor(0.9428, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_1
# tensor(0.9451, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_0
# tensor(0.6971, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_32_l2p_1
# tensor(0.9148, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_1
# tensor(0.9909, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_0.001
# tensor(0.4541, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_1
# tensor(5.5746, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_8_l2p_0
# tensor(0.4034, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_0
# tensor(1.0311, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_32_l2p_1
# tensor(0.9526, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_0.001
# tensor(0.3231, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_0.001
# tensor(3.1224, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_1
# tensor(0.8129, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_0
# tensor(0.7020, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_0.001
# tensor(0.8437, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_0
# tensor(0.6409, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_1
# tensor(1.4537, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0
# tensor(0.6302, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_0.001
# tensor(0.3583, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_0
# tensor(0.6023, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_0
# tensor(0.2081, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_1
# tensor(1.0168, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_32_l2p_1
# tensor(0.9643, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_0.001
# tensor(0.3594, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_0
# tensor(0.5755, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_8_l2p_0.001
# tensor(0.7038, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0
# tensor(0.6991, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_0
# tensor(0.3785, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_0
# tensor(0.6501, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_1
# tensor(0.9185, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_1
# tensor(0.9248, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_8_l2p_1
# tensor(0.9357, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_1
# tensor(0.9416, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_0.001
# tensor(0.7142, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_32_l2p_0
# tensor(0.5817, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_32_l2p_0
# tensor(0.4113, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_32_l2p_0.001
# tensor(0.6926, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_32_l2p_0
# tensor(0.6941, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_0
# tensor(0.6958, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_1
# tensor(0.9395, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_32_l2p_0
# tensor(0.6957, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_0.001
# tensor(0.6932, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_0
# tensor(0.4021, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_32_l2p_0.001
# tensor(0.5113, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_8_l2p_1
# tensor(0.9733, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_0.001
# tensor(0.6956, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_32_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_128_l2p_0.001
# tensor(0.6025, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_8_l2p_0
# tensor(0.7317, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_128_l2p_1
# tensor(0.9088, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_32_l2p_0.001
# tensor(0.6967, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6943, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_8_l2p_0.001
# tensor(0.5913, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_128_l2p_0.001
# tensor(2.4155, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_8_l2p_0.001
# tensor(0.0198, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_128_l2p_0.001
# tensor(0.6958, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_32_l2p_1
# tensor(0.9090, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_128_l2p_1
# tensor(0.9463, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_32_l2p_0
# tensor(0.4623, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_0.001
# tensor(0.4991, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_32_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_1
# tensor(0.9462, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_1
# tensor(1.1759, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_32_l2p_0
# tensor(0.7016, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_32_l2p_0.001
# tensor(0.0072, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_8_l2p_0
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_8_l2p_1
# tensor(0.8917, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_8_l2p_0.001
# tensor(0.0015, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_32_l2p_1
# tensor(1.0294, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_8_l2p_1
# tensor(0.9546, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_0.001
# tensor(0.3327, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_128_l2p_1
# tensor(2.4726, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_32_l2p_0
# tensor(0.0010, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_128_l2p_0
# tensor(0.6256, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_32_l2p_1
# tensor(0.7811, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_8_l2p_1
# tensor(0.9448, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_1
# tensor(0.9456, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_128_l2p_0.001
# tensor(0.6915, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_128_l2p_1
# tensor(0.9749, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_8_l2p_0
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_128_l2p_0.001
# tensor(0.7662, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_0
# tensor(0.3780, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_128_l2p_0.001
# tensor(0.3434, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_128_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_8_l2p_0.001
# tensor(0.8240, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6968, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_8_l2p_0
# tensor(0.7090, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_0.001
# tensor(0.6967, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_128_l2p_1
# tensor(1.0806, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_128_l2p_1
# tensor(0.8990, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_1
# tensor(0.9442, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_0
# tensor(0.5323, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_8_l2p_0.001
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_128_l2p_0.001
# tensor(0.0004, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_8_l2p_0.001
# tensor(0.0125, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6772, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_128_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_8_l2p_0.001
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_1
# tensor(0.7978, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_1
# tensor(1.0418, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_0
# tensor(0.8040, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_1
# tensor(0.9509, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_128_l2p_1
# tensor(0.7805, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_8_l2p_0
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_128_l2p_0
# tensor(0.7646, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_32_l2p_1
# tensor(0.9460, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_1
# tensor(0.9897, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_0.001
# tensor(0.4725, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_1
# tensor(2.9891, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_8_l2p_0
# tensor(0.1079, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_8_l2p_0
# tensor(0.0001, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_0
# tensor(0.6475, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_8_l2p_0
# tensor(0.0022, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_8_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_0
# tensor(4.3548, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_128_l2p_0
# tensor(0.6250, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_32_l2p_1
# tensor(0.9501, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_32_l2p_0.001
# tensor(0.0074, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_128_l2p_1
# tensor(0.9441, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_0.001
# tensor(0.6961, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_0.001
# tensor(3.1013, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_32_l2p_1
# tensor(0.9174, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_1
# tensor(0.7611, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_0
# tensor(0.6173, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_32_l2p_0
# tensor(0.6980, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_128_l2p_0
# tensor(2.4174e-05, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_0.001
# tensor(0.6960, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_0
# tensor(0.6501, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_8_l2p_1
# tensor(0.7640, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_8_l2p_0
# tensor(0.6957, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_32_l2p_0
# tensor(0.5076, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_1
# tensor(0.8050, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_8_l2p_1
# tensor(1.1549, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0.001
# tensor(0.3043, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0
# tensor(0.6953, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_0.001
# tensor(0.4791, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_32_l2p_0.001
# tensor(0.2875, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_8_l2p_1
# tensor(0.9012, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_0.001
# tensor(0.3844, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0
# tensor(0.4270, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_0
# tensor(0.6517, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_32_l2p_1
# tensor(0.9403, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_32_l2p_0
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_0.001
# tensor(0.3084, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_128_l2p_0.001
# tensor(0.2233, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_0
# tensor(0.2754, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_1
# tensor(0.9297, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_128_l2p_0
# tensor(0.6826, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_32_l2p_1
# tensor(0.8919, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_0
# tensor(0.6423, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_8_l2p_1
# tensor(1.0968, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_32_l2p_0.001
# tensor(0.7937, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_8_l2p_1
# tensor(0.9583, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_128_l2p_0
# tensor(0.5104, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_8_l2p_0.001
# tensor(0.7131, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0
# tensor(0.6961, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_8_l2p_1
# tensor(0.9344, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6824, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_128_l2p_0
# tensor(0.6673, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_0
# tensor(0.5221, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_8_l2p_0.001
# tensor(0.6958, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_128_l2p_0
# tensor(0.0025, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_128_l2p_0
# tensor(3.3176, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_1
# tensor(1.2804, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_8_l2p_0.001
# tensor(0.0387, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_1
# tensor(0.9321, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_8_l2p_1
# tensor(1.0029, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_32_l2p_1
# tensor(0.9537, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_1
# tensor(0.9410, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_32_l2p_1
# tensor(0.9953, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_0.001
# tensor(2.1183, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_32_l2p_0.001
# tensor(0.6960, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_128_l2p_0.001
# tensor(0.0007, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_8_l2p_0.001
# tensor(0.0036, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_32_l2p_1
# tensor(1.7838, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_32_l2p_0
# tensor(0.5655, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_32_l2p_0
# tensor(0.3611, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_32_l2p_0
# tensor(0.8596, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_32_l2p_0.001
# tensor(0.6753, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_32_l2p_0
# tensor(0.6959, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_32_l2p_0
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_8_l2p_1
# tensor(0.9426, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_0
# tensor(0.7460, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0
# tensor(0.6845, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_32_l2p_0
# tensor(0.6946, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_128_l2p_0.001
# tensor(0.6903, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.001_bs_8_l2p_0.001
# tensor(0.5541, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_8_l2p_1
# tensor(0.9468, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_1
# tensor(1.1072, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_32_l2p_0
# tensor(0.6956, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_0.001
# tensor(0.6916, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_0
# tensor(0.5578, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_32_l2p_0.001
# tensor(0.4728, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_32_l2p_0.001
# tensor(0.5690, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.001_bs_8_l2p_1
# tensor(0.9491, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_8_l2p_1
# tensor(0.9439, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_128_l2p_0
# tensor(0.7019, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_0.001
# tensor(0.7024, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.001_bs_8_l2p_0
# tensor(0.4788, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_32_l2p_0.001
# tensor(0.0020, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_32_l2p_0.001
# tensor(0.6957, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_0
# tensor(0.6097, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_128_l2p_0.001
# tensor(0.6717, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_32_l2p_1
# tensor(1.0036, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_8_l2p_0
# tensor(0.7842, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_128_l2p_1
# tensor(0.9233, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_128_l2p_0.001
# tensor(0.5558, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_32_l2p_0.001
# tensor(0.6991, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_8_l2p_0
# tensor(4.2730e-05, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6841, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_8_l2p_0.001
# tensor(0.3503, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_128_l2p_0.001
# tensor(3.3941, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_8_l2p_0.001
# tensor(0.0077, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_128_l2p_0.001
# tensor(0.6854, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_32_l2p_1
# tensor(0.9978, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_128_l2p_1
# tensor(0.9450, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_32_l2p_0
# tensor(0.4328, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_0.001
# tensor(0.3254, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_32_l2p_0.001
# tensor(0.6969, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_1
# tensor(0.9458, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_1
# tensor(1.4748, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_32_l2p_0
# tensor(0.6962, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_32_l2p_0.001
# tensor(0.0037, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_8_l2p_0
# tensor(5.7745e-05, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_8_l2p_1
# tensor(0.9071, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_8_l2p_0.001
# tensor(0.0013, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_32_l2p_1
# tensor(0.9748, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_8_l2p_1
# tensor(0.9813, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.01_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_0.001
# tensor(0.6577, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.001_bs_32_l2p_0.001
# tensor(0.6631, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_128_l2p_1
# tensor(3.1348, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_32_l2p_0
# tensor(0.0045, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_128_l2p_0
# tensor(0.6646, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_32_l2p_1
# tensor(0.7819, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_8_l2p_1
# tensor(0.9455, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_1
# tensor(0.9446, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_128_l2p_0.001
# tensor(0.6894, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_128_l2p_1
# tensor(0.8844, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_128_l2p_0
# tensor(0.7016, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.0001_bs_128_l2p_0.001
# tensor(0.0003, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_8_l2p_0
# tensor(5.0510e-05, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_128_l2p_0.001
# tensor(0.7671, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_0
# tensor(0.3601, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_128_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.1_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_128_l2p_0
# tensor(2.4790, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_128_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_128_l2p_0.001
# tensor(0.5608, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_128_l2p_1
# tensor(0.9447, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_128_l2p_0.001
# tensor(0.0012, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_128_l2p_0.001
# tensor(0.7069, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_8_l2p_0.001
# tensor(0.7076, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0.001
# tensor(0.7091, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_8_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_0.001
# tensor(0.6956, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_128_l2p_1
# tensor(0.8326, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_128_l2p_0
# tensor(0.4784, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_128_l2p_1
# tensor(0.9671, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_1
# tensor(0.9455, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_32_l2p_0
# tensor(0.4940, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_8_l2p_0.001
# tensor(0.0031, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_128_l2p_0.001
# tensor(0.0029, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_8_l2p_0.001
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_0.001
# tensor(0.7018, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_32_l2p_0.001
# tensor(0.6304, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_32_l2p_1
# tensor(0.9261, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_32_l2p_0
# tensor(0.0404, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_128_l2p_0.001
# tensor(0.3502, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_8_l2p_0.001
# tensor(0.0076, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.01_bs_8_l2p_1
# tensor(0.9571, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_32_l2p_0.001
# tensor(0.7269, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_128_l2p_1
# tensor(0.9446, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.0001_bs_8_l2p_0
# tensor(3.6347e-05, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.01_bs_32_l2p_0
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.001_bs_8_l2p_1
# tensor(0.9466, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_1
# tensor(0.8013, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_1
# tensor(0.9376, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_32_l2p_0
# tensor(0.6495, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_0
# tensor(1.5487, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_1
# tensor(0.9723, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_128_l2p_1
# tensor(0.7792, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.001_bs_8_l2p_0
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_8_l2p_0
# tensor(0.0023, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.1_bs_32_l2p_1
# tensor(0.7347, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_128_l2p_0
# tensor(0.6950, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.01_bs_32_l2p_1
# tensor(0.9358, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_32_l2p_1
# tensor(1.1152, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_1
# tensor(0.9621, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_0.001
# tensor(0.2798, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.001_bs_128_l2p_0.001
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_1
# tensor(3.8606, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_8_l2p_0
# tensor(0.1528, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_8_l2p_0
# tensor(3.4680e-05, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.001_bs_8_l2p_0
# tensor(0.6582, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.001_bs_128_l2p_1
# tensor(0.9237, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_8_l2p_0
# tensor(0.0319, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_8_l2p_0
# tensor(0.6955, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_0
# tensor(3.8762, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_128_l2p_0
# tensor(0.4539, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_32_l2p_1
# tensor(1.0213, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.0001_bs_8_l2p_0.001
# tensor(0.0005, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_32_l2p_0.001
# tensor(0.0554, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_128_l2p_1
# tensor(0.9442, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_8_l2p_0.001
# tensor(0.7006, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_128_l2p_1
# tensor(2.3948, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.001_bs_32_l2p_1
# tensor(0.9186, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_128_l2p_0.001
# tensor(3.7066, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.001_bs_32_l2p_1
# tensor(0.9380, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_8_l2p_1
# tensor(1.0506, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.01_bs_8_l2p_0
# tensor(0.5394, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_32_l2p_0
# tensor(0.7043, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.01_bs_128_l2p_0
# tensor(8.1470e-06, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_128_l2p_0
# tensor(9.6906e-06, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_32_l2p_0.001
# tensor(0.7058, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_0
# tensor(0.2945, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_32_l2p_0.001
# tensor(0.0018, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.0001_bs_128_l2p_0
# tensor(0.0016, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_8_l2p_1
# tensor(3.4300, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_8_l2p_0
# tensor(0.7094, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.01_bs_8_l2p_0
# tensor(0.0249, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_32_l2p_0
# tensor(0.3856, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_32_l2p_1
# tensor(2.0966, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_8_l2p_1
# tensor(0.8884, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0.001
# tensor(0.3094, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0
# tensor(0.6882, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.001_bs_32_l2p_1
# tensor(0.9142, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_128_l2p_0.001
# tensor(2.3290, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.1_bs_128_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.0001_bs_32_l2p_0.001
# tensor(0.3196, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_32_l2p_1
# tensor(0.9895, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_8_l2p_1
# tensor(0.8087, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.001_bs_8_l2p_0.001
# tensor(0.5937, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.01_bs_8_l2p_0.001
# tensor(0.0059, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.0001_bs_8_l2p_0
# tensor(0.3377, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_128_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_32_l2p_0.001
# tensor(0.1682, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_32_l2p_1
# tensor(0.9583, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_32_l2p_0
# tensor(0.0002, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_0.001
# tensor(0.6269, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_128_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_8_l2p_0
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_1
# tensor(0.7883, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.001_bs_128_l2p_0
# tensor(0.6952, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.1_bs_8_l2p_0.001
# tensor(0.7026, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.01_bs_32_l2p_1
# tensor(0.9666, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.0001_bs_8_l2p_1
# tensor(0.9319, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_32_l2p_0.001
# tensor(0.4950, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_128_opt_Adam_lr_0.1_bs_32_l2p_0.001
# tensor(0.6954, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_Adam_lr_0.0001_bs_8_l2p_0
# tensor(1.2259, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.01_bs_128_l2p_0
# tensor(0.5659, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.1_bs_32_l2p_1
# tensor(0.8547, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_8_l2p_1
# tensor(0.8916, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_32_l2p_0.001
# tensor(1.1552, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_128_l2p_1
# tensor(0.9454, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.001_bs_8_l2p_1
# tensor(0.9501, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_128_l2p_0
# tensor(0.3009, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.9_lr_0.1_bs_8_l2p_0.001
# tensor(0.7825, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0
# tensor(0.6829, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.1_bs_128_l2p_0.001
# tensor(0.1664, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.9_lr_0.01_bs_8_l2p_1
# tensor(0.9508, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.001_bs_32_l2p_0
# tensor(0.6414, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.1_bs_32_l2p_0.001
# tensor(0.7582, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_SGD_0.0_lr_0.0001_bs_8_l2p_0.001
# tensor(0.6958, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_8_l2p_0
# tensor(0.2917, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_4_opt_SGD_0.0_lr_0.01_bs_128_l2p_0
# tensor(0.6933, grad_fn=<MseLossBackward0>)
# nn_depth_4_width_32_opt_Adam_lr_0.1_bs_128_l2p_1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [38], line 27
#      25 for nn_type in os.listdir(model_dir_path / func_name / dim / N / data_gen_method):
#      26     print(nn_type)
# ---> 27     net = load_model(model_dir_path / func_name / dim / N / data_gen_method / nn_type / "model.pt")
#      29     # forward + backward + optimize
#      30     outputs = net(X_data)
#
# Cell In [37], line 13, in load_model(path)
#      10 dim = int(dim)
#      12 model = SimpleNet(dim, 1, width, depth)
# ---> 13 model.load_state_dict(torch.load(path))
#      14 model.eval()
#      15 return model
#
# File ~/miniconda3/envs/interp/lib/python3.10/site-packages/torch/serialization.py:700, in load(f, map_location, pickle_module, **pickle_load_args)
#     697     pickle_load_args['encoding'] = 'utf-8'
#     699 with _open_file_like(f, 'rb') as opened_file:
# --> 700     if _is_zipfile(opened_file):
#     701         # The zipfile reader is going to advance the current file position.
#     702         # If we want to actually tail call to torch.jit.load, we need to
#     703         # reset back to the original position.
#     704         orig_position = opened_file.tell()
#     705         with _open_zipfile_reader(opened_file) as opened_zipfile:
#
# File ~/miniconda3/envs/interp/lib/python3.10/site-packages/torch/serialization.py:58, in _is_zipfile(f)
#      55 read_bytes = []
#      56 start = f.tell()
# ---> 58 byte = f.read(1)
#      59 while byte != "":
#      60     read_bytes.append(byte)
#
# KeyboardInterrupt:

# %% [markdown]
# # schwefel stuff

# %%
dim = 1
N = 10000

num_steps = 1e4

X_data, y_data = load_fast("Schwefel", dim, N, "HessSampling")
X_data /= 100
y_data = (y_data - 400) / 100


inp_dim=dim
eps = 5e-3
width = 128
num_layers = 3
optimizer_name = "SGD"
lr = 1e-1
weight_decay = 0
batch_size = 16
num_epochs = int(1. * num_steps / (N / batch_size))



net, loss_hist = train(inp_dim, None, X_data, y_data, num_epochs, eps, width, num_layers, optimizer_name, lr, batch_size, weight_decay, momentum=0, verbose=True)

save_nn(nn, loss_hist, "Schwefel", dim, N, "HessSampling", num_layers, width, optimizer, lr, batch_size, weight_decay, momentum=0)
# Out:
# 100%|██████████| 16/16 [00:09<00:00,  1.69it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [165], line 25
#      19 num_epochs = int(1. * num_steps / (N / batch_size))
#      23 net, loss_hist = train(inp_dim, None, X_data, y_data, num_epochs, eps, width, num_layers, optimizer_name, lr, batch_size, weight_decay, momentum=0, verbose=True)
# ---> 25 save_nn(nn, loss_hist, "Schwefel", dim, N, data_gen_name, num_layers, width, optimizer, lr, batch_size, weight_decay, momentum=0)
#
# NameError: name 'data_gen_name' is not defined

# %%
import matplotlib.pyplot as plt 

plt.plot([float(l) for l in loss_hist])
plt.yscale("log")

# %%
from Functions import Schwefel
import numpy as np

# %%
X_test = np.random.uniform(low=-5, high=5, size=(1000, dim))
y_test = F.f(X_test) / 

nn_out = net(Tensor(X_test.reshape(-1, 1)))

np.linalg.norm(y_test - nn_out.detach().numpy())

# %%
X_test = np.random.uniform(low=-5, high=5, size=(1000, dim))
y_test = (F.f(X_test*100) - 400)/100

nn_out = net(Tensor(X_test.reshape(-1, 1)))

np.linalg.norm(y_test - nn_out.detach().numpy())
# Out:
# 2699.346

# %%
Xs = Xs / 50
net_out = net(Tensor(Xs.reshape(-1, 1)))

# %%
plt.scatter(Xs, [float(o) for o in net_out])

# %%
F = Schwefel()

Xs = np.linspace(F.bounds[0][0], F.bounds[0][1], 1000)
ys = F.f(Xs.reshape(-1, 1))
plt.plot(Xs, ys)

# %%
plt.scatter(X_data, y_data)
